# %% [markdown]
# <a href="https://colab.research.google.com/github/christinatras/AAI2026/blob/dev/BUS4_118S_Prompt_Engineering_EXERCISE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXERCISE 3
# Self Reflection
#
# Prompt: Write a minimum 150-word summary explaining how artificial intelligence is changing business operations, focusing on automation, decision-making, and productivity. The summary should be written for a general student audience.
#
# - Accuracy
# - Clarity
# - Audience appropriateness
# - Length (150+ words)
# - Organization and readability

# %% [markdown]
# ChatGPT Response: Artificial intelligence (AI) is transforming how businesses operate by improving automation, decision-making, and productivity. Many companies now use AI to automate routine tasks such as data entry, customer service responses, and inventory management. This reduces manual work and allows employees to focus on more strategic and creative responsibilities. AI also supports better decision-making by quickly analyzing large amounts of data and identifying patterns that humans might miss. For example, businesses can use AI to predict customer demand, optimize pricing, or detect potential risks. In addition, AI tools help increase productivity by streamlining workflows and improving efficiency across departments such as marketing, finance, and operations. While AI does not replace all human roles, it often works alongside employees to enhance their capabilities. As a result, organizations can operate faster, make more informed decisions, and deliver better services to customers in an increasingly competitive business environment.

# %% [markdown]
# ME: Revise answer to be answered in a tone that is specific to college students, this should not be highly analytical but rather digestible to any major.

# %% [markdown]
# ChatGPT Response: Artificial intelligence (AI) is changing how businesses work by helping companies automate tasks, make better decisions, and improve productivity. Many businesses use AI to handle repetitive tasks like organizing data, answering basic customer questions, or tracking inventory. This saves time and allows employees to focus on more creative or strategic work. AI also helps businesses make smarter decisions by analyzing large amounts of data quickly and identifying patterns that people might miss. For example, companies can use AI to predict what products customers might want or to adjust prices based on demand. These tools also help teams work more efficiently by speeding up processes and reducing errors. Instead of replacing workers, AI often acts as a tool that supports employees and helps them do their jobs better. As AI continues to grow, businesses can operate more efficiently and respond more quickly to changes in the market.

# %% [markdown]
# ME: This is not over 150 words.

# %% [markdown]
# ChatGPT Response: Here is a ~175-word version (safely over 150) while keeping the college-student friendly tone:
#
# Artificial intelligence (AI) is changing how businesses operate in ways that are easy for college students to understand. Many companies now use AI to automate repetitive tasks such as answering basic customer questions, organizing large sets of data, scheduling meetings, and tracking inventory. By handling these routine activities, AI saves time and allows employees to focus on more meaningful work that involves creativity, collaboration, and problem solving. AI also helps businesses make smarter decisions by quickly analyzing large amounts of information and identifying patterns that might take humans much longer to notice. For example, companies can use AI to predict which products customers may want to buy, improve marketing strategies, or adjust prices based on trends and demand. Productivity also improves because AI can streamline workflows and reduce the chances of human error. Instead of replacing workers entirely, AI often acts as a helpful tool that supports employees and helps them work more efficiently. As AI technology continues to grow, businesses are becoming faster, more adaptable, and better prepared to respond to customer needs in a competitive and constantly changing market.
